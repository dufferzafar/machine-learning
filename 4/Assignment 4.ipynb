# %%
import random

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

# Open CV
import cv2

# Python stdlib
from collections import Counter

# Algorithms from scikit-learn
from sklearn.cluster import KMeans
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.svm import SVC


# My Code
from common import load_data, write_csv, accuracy, imshow
# from q1_c_nn import *

# Autoreload modules on change
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
trX, trY, tsX = load_data()

classes, trYi = np.unique(trY, return_inverse=True)

# %%
# SVM Pipeline
svm_pipeline = Pipeline([
    # Normalize data to zero mean & unit variance
    ('scaler', StandardScaler()),

    # Project data down to 50 principal components
    ('pca', PCA(n_components=50)),

    # Learn a hyperplane in that space
    ('clf', SVC(kernel="linear")),
])

# %%
# svm_pipeline.set_params(pca__n_components=250)
# svm_pipeline.set_params(clf__kernel="rbf")
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
# trX_ = np.fromiter((cv2.erode(img, kernel) for img in trX), trX.dtype)

# %%
imshow(trX_[9])

# %%
r, c = 4, 5
f, axs = plt.subplots(2*r, c, figsize=(12, 18), facecolor='white')

img_idx = random.randrange(5000)

for i in range(0, 2*r, 2):
    for j in range(c):
        
        img = trX[img_idx]
        img_ = cv2.erode(img, kernel)
#         img_ = cv2.dilate(img_, kernel)
        
        axs[i, j].imshow(img.reshape(28, 28))
        axs[i, j].set_title(trY[img_idx])
        axs[i, j].axis('off')
        
        axs[i+1, j].imshow(img_.reshape(28, 28))
        axs[i+1, j].set_title(trY[img_idx])
        axs[i+1, j].axis('off')
        
        img_idx += 5000
        
f.savefig("before_after.png")

# %%
kernel = np.ones((2, 1))

for i in range(1, 100000, 5000):
    img, cls = trX[i], trY[i]
    
    print(cls)
    
    imshow(img)
    
    img = cv2.erode(img, kernel)
#     img = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
    
    imshow(img)
# Out:
# banana
# bulldozer
# chair
# eyeglasses
# flashlight
# foot
# hand
# harp
# hat
# keyboard
# laptop
# nose
# parrot
# penguin
# pig
# skyscraper
# snowman
# spider
# trombone
# violin

# %%
img = trX[4]
# imshow(img)


kernel = np.ones((2, 1))

# print(img)

img = cv2.erode(img, kernel)
imshow(img)

# img = np.where(img < 150, img + 150, img)

# img *= 255
# img = cv2.dilate(img, np.ones((2, 2)), iterations = 1)
# img = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
# img = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)
# img = cv2.morphologyEx(img, cv2.MORPH_TOPHAT, kernel)

imshow(img)

# %%
train_data = DataLoader(dataset=TrainingData(),
                        batch_size=batch_size, shuffle=True)

# %%
classes[predict(net, train_data)]
# Out:
# array(['hat', 'spider', 'foot', ..., 'harp', 'foot', 'parrot'],
#       dtype='<U10')

# %%
np.arange(5, 8, 2)
# Out:
# array([5, 7])

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

# %%
trX_, tvX_, trY_, tvY_ = train_test_split(trX, trY, test_size=0.4)

# %%
len(trX_), len(tvX_)
# Out:
# (60000, 40000)
